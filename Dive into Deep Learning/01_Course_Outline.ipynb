# %% [markdown]
# # 课程安排

# %% [markdown]
# 课程安排分三部分：

# %% [markdown]
# 1. 介绍深度学习经典与最新模型
# 2. 机器学习基础
# 3. 使用Pytorch实现

# %% [markdown]
# 内容： 深度学习基础 ；

# %% [markdown]
# 卷积神经网络 ；循环神经网络 ；注意力机制 ；优化算法 ；高性能计算 ；计算机视觉 ；自然语言处理
